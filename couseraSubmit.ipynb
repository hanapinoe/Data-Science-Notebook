# %% [markdown]
# # Data Science Tools and Techniques

# %% [markdown]
# ## Introduction
# This notebook explores the essential tools, languages, and libraries used in data science. It demonstrates basic arithmetic operations, data manipulation, and visualization techniques while showcasing the functionality of Jupyter Notebooks. The goal is to provide a concise overview for beginners in data science.

# %% [markdown]
# ## Data Science Languages
# Here are some popular programming languages used in data science:
# - **Python**: Widely used for its versatility and extensive libraries.
# - **R**: Preferred for statistical analysis and visualization.
# - **Julia**: Known for high-performance numerical computing.
# - **SQL**: Essential for database querying and data manipulation.

# %% [markdown]
# ## Data Science Libraries
# Below are key libraries commonly used in data science:
# - **NumPy**: For numerical computations in Python.
# - **Pandas**: For data manipulation and analysis in Python.
# - **ggplot2**: For data visualization in R.
# - **caret**: For machine learning in R.
# - **Matplotlib**: For plotting in Python.

# %% [markdown]
# ## Data Science Tools
# | Tool          | Description                              |
# |---------------|------------------------------------------|
# | Jupyter       | Interactive notebook environment         |
# | RStudio       | IDE for R programming                    |
# | Google Colab  | Cloud-based Jupyter Notebook platform    |
# | GitHub        | Version control and collaboration tool   |
# | Anaconda      | Distribution for Python/R with package management |

# %% [markdown]
# ## Arithmetic Expression Examples
# In this section, we’ll explore simple arithmetic operations like multiplication and addition, as well as unit conversions, using code cells to demonstrate how these can be implemented programmatically.

# %%
# Multiply and add numbers
a = 5
b = 3
result = (a * b) + 2
print(f"Multiplying {a} and {b}, then adding 2 gives: {result}")

# %%
# Convert minutes to hours
minutes = 120
hours = minutes / 60
print(f"{minutes} minutes is equal to {hours} hours")

# %% [markdown]
# ## Objectives
# - Learn the basics of Jupyter Notebooks and their use in data science.
# - Understand key data science languages and libraries.
# - Demonstrate simple arithmetic operations and conversions in code.
# - Share and collaborate on projects using GitHub.

# %% [markdown]
# ## Author
# **Author:** [Phuc Phan Cong]
